# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_Mul_linear.sav",'rb'))

# %%
rd=float(input("R&D:"))
admin=float(input("Admin:"))
mark=float(input("Marketing:"))
St_flo=int(input("State_Florida - 0 or 1:"))
St_ny=int(input("State_NY - 0 or 1:"))
# Out:
# R&D: 34563.54
# Admin: 65879.43
# Marketing: 26873.34
# State_Florida - 0 or 1: 0
# State_NY - 0 or 1: 0

# %%
result=loaded_model.predict([[rd,admin,mark,St_flo,St_ny]])
result
# Out:
# /Users/user/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[72560.93150022]])
