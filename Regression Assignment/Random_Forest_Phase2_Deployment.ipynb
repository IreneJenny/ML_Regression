# %%
import pickle
loaded_model=pickle.load(open("finalized_model_Random_Forest.sav",'rb'))
result=loaded_model.predict([[35,25.45,0,0,0]])
# Out:
# /Users/user/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([5045.2693945])
