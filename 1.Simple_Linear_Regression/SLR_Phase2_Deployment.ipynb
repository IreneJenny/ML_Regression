# %%
# Importing pickle module from the python standard library

import pickle

# %%
# pickle.load will load the data from the file (byte stream) to the active program memory (as python object structure).
                                   
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb'))

# %%
# then it will predict the output from the input data
# output is assigned to the variable named result

result=loaded_model.predict([[13]])
result
# Out:
# /Users/user/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[148460.78806172]])
